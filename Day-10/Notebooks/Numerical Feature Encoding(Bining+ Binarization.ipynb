# %% [markdown]
# # Numerical Feature Encoding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %% [markdown]
# Numeric encoding of features is used when working with machine learning algorithms that require numeric inputs or when you need to represent categorical or ordinal variables in a numerical format for analysis and modeling purposes.

# %% [markdown]
# ![image.png](attachment:836e7efa-704d-49f5-bc38-0f7bbd5b62b8.png)

# %%
So here we are going to pratice how to encode the numerical data

# %%
dataset=pd.read_csv('C:/Users/ACER/Desktop/Wild Animal Final/Dataset1/labels.csv')

# %%
dataset.sample(5)
# Out:
#                                               Image_Path  \
# 67197  C:/Users/ACER/Desktop/Wild Animal Final/Datase...
# 71413  C:/Users/ACER/Desktop/Wild Animal Final/Datase...
# 47653  C:/Users/ACER/Desktop/Wild Animal Final/Datase...
# 38329  C:/Users/ACER/Desktop/Wild Animal Final/Datase...
# 78289  C:/Users/ACER/Desktop/Wild Animal Final/Datase...
#
#                                                 TXT_Path      Name  Xmin  \
# 67197  C:/Users/ACER/Desktop/Wild Animal Final/Datase...     Sheep     2
# 71413  C:/Users/ACER/Desktop/Wild Animal Final/Datase...     Tiger   806
# 47653  C:/Users/ACER/Desktop/Wild Animal Final/Datase...  Kangaroo   264
# 38329  C:/Users/ACER/Desktop/Wild Animal Final/Datase...       Dog   302
# 78289  C:/Users/ACER/Desktop/Wild Animal Final/Datase...     Zebra   277
#
#        Xmax  Ymin  Ymax
# 67197   303   205   475
# 71413   895   691   754
# 47653   507   209   435
# 38329   900    89   767
# 78289   371   173   273

# %%
dataset.shape
# Out:
# (79802, 7)

# %%
dataset.duplicated().sum()
# Out:
# 7

# %%
dataset.isnull().sum()
# Out:
# Image_Path    0
# TXT_Path      0
# Name          0
# Xmin          0
# Xmax          0
# Ymin          0
# Ymax          0
# dtype: int64
